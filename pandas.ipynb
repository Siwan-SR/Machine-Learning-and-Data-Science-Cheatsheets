# %% [markdown]
# <a href="https://colab.research.google.com/github/Siwan-SR/Machine-Learning-and-Data-Science-Cheatsheets/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# 2 main datatypes


series = pd.Series(["BMW", "Toyota", "Honda"])
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1 - dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# Datafram = 2 - dimensional


car_data = pd.DataFrame({

                        "Car make": series, 
                        "Colour": colours,
                         
                         })

car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Importing Data

# car_sales = pd.read_csv("https://docs.google.com/spreadsheets/d/1B9Vt3-PEDwD1CSFhVHPbBqjnSXvHtVUaKlEOW6v5MQ4/")
# car_sales

# %%
# Exporting a Dataframe

car_sales.to_csv("exported-car-sales.csv")

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv", index = False)
exported_car_sales

# %% [markdown]
# ### Describing Data

# %%
# Creating a Data Frame to test


series = pd.Series(["Toyota", "Honda", "Toyota", "BMW", "Nissan", "Toyota", "Honda", "Honda", "Toyota", "Nissan"])
colours = pd.Series(["White", "Red", "Blue", "Black", "White", "Green", "Blue", "Blue", "White", "White"])
doors = pd.Series(["4", "4", "3", "5", "4", "4", "4", "4", "4", "4"])
odometer = pd.Series([150043, 87899, 32549, 11179, 213095, 99213, 45698, 54738, 60000, 31600])
price = pd.Series(["$4,000.00", "$5,000.00", "$7,000.00", "$22,000.00", "$3,500.00", "$4,500.00", "$7,500.00", "$7,000.00", "$6,250.00", "$9,700.00"])


cars = pd.DataFrame({

                    "Make": series,
                    "Colour": colours,
                    "Odometer (KM)": odometer,
                    "Doors": doors,
                    "Price": price,
                     
                    })

cars
# Out:
#      Make Colour  Odometer (KM) Doors       Price
# 0  Toyota  White         150043     4   $4,000.00
# 1   Honda    Red          87899     4   $5,000.00
# 2  Toyota   Blue          32549     3   $7,000.00
# 3     BMW  Black          11179     5  $22,000.00
# 4  Nissan  White         213095     4   $3,500.00
# 5  Toyota  Green          99213     4   $4,500.00
# 6   Honda   Blue          45698     4   $7,500.00
# 7   Honda   Blue          54738     4   $7,000.00
# 8  Toyota  White          60000     4   $6,250.00
# 9  Nissan  White          31600     4   $9,700.00

# %%
# Attribute


cars.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors            object
# Price            object
# dtype: object

# %%
car_columns = cars.columns 
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
cars.describe()
# Out:
#        Odometer (KM)
# count      10.000000
# mean    78601.400000
# std     61983.471735
# min     11179.000000
# 25%     35836.250000
# 50%     57369.000000
# 75%     96384.500000
# max    213095.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     object
#  4   Price          10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 528.0+ bytes

# %%
cars.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Odometer (KM)        78601.4
# Doors            443544444.4
# dtype: float64

# %%
car_prices = pd.Series([300, 1500, 111250])
car_prices.mean()
# Out:
# 37683.333333333336

# %%
cars.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                   4435444444
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
cars["Doors"].sum()
# Out:
# '4435444444'

# %%
len(cars)
# Out:
# 10

# %% [markdown]
# ### Viewing and Selecting Data

# %%
cars.head()
# Out:
#      Make Colour  Odometer (KM) Doors       Price
# 0  Toyota  White         150043     4   $4,000.00
# 1   Honda    Red          87899     4   $5,000.00
# 2  Toyota   Blue          32549     3   $7,000.00
# 3     BMW  Black          11179     5  $22,000.00
# 4  Nissan  White         213095     4   $3,500.00

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors       Price
# 0  Toyota  White         150043     4   $4,000.00
# 1   Honda    Red          87899     4   $5,000.00
# 2  Toyota   Blue          32549     3   $7,000.00
# 3     BMW  Black          11179     5  $22,000.00
# 4  Nissan  White         213095     4   $3,500.00
# 5  Toyota  Green          99213     4   $4,500.00
# 6   Honda   Blue          45698     4   $7,500.00
# 7   Honda   Blue          54738     4   $7,000.00
# 8  Toyota  White          60000     4   $6,250.00
# 9  Nissan  White          31600     4   $9,700.00

# %%
cars.head(7)
# Out:
#      Make Colour  Odometer (KM) Doors       Price
# 0  Toyota  White         150043     4   $4,000.00
# 1   Honda    Red          87899     4   $5,000.00
# 2  Toyota   Blue          32549     3   $7,000.00
# 3     BMW  Black          11179     5  $22,000.00
# 4  Nissan  White         213095     4   $3,500.00
# 5  Toyota  Green          99213     4   $4,500.00
# 6   Honda   Blue          45698     4   $7,500.00

# %%
cars.tail(3)
# Out:
#      Make Colour  Odometer (KM) Doors      Price
# 7   Honda   Blue          54738     4  $7,000.00
# 8  Toyota  White          60000     4  $6,250.00
# 9  Nissan  White          31600     4  $9,700.00

# %%
# .loc & .iloc


animals = pd.Series(["cat", "dog", "bird", "panda", "snake"],
                    
                    index = [0, 3, 9, 8, 3]
                    
                    )


animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
cars.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position

animals.iloc[3]
# Out:
# 'panda'

# %%
# .loc refers to index


cars.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors       Price
# 0  Toyota  White         150043     4   $4,000.00
# 1   Honda    Red          87899     4   $5,000.00
# 2  Toyota   Blue          32549     3   $7,000.00
# 3     BMW  Black          11179     5  $22,000.00
# 4  Nissan  White         213095     4   $3,500.00
# 5  Toyota  Green          99213     4   $4,500.00
# 6   Honda   Blue          45698     4   $7,500.00
# 7   Honda   Blue          54738     4   $7,000.00
# 8  Toyota  White          60000     4   $6,250.00
# 9  Nissan  White          31600     4   $9,700.00

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
cars.iloc[:3]
# Out:
#      Make Colour  Odometer (KM) Doors      Price
# 0  Toyota  White         150043     4  $4,000.00
# 1   Honda    Red          87899     4  $5,000.00
# 2  Toyota   Blue          32549     3  $7,000.00

# %%
cars.head(4)
# Out:
#      Make Colour  Odometer (KM) Doors       Price
# 0  Toyota  White         150043     4   $4,000.00
# 1   Honda    Red          87899     4   $5,000.00
# 2  Toyota   Blue          32549     3   $7,000.00
# 3     BMW  Black          11179     5  $22,000.00

# %%
cars["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
cars["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
cars.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
cars["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
cars[cars["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM) Doors      Price
# 0  Toyota  White         150043     4  $4,000.00
# 2  Toyota   Blue          32549     3  $7,000.00
# 5  Toyota  Green          99213     4  $4,500.00
# 8  Toyota  White          60000     4  $6,250.00

# %%
pd.crosstab(cars["Make"], cars["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby


cars.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)
# Make
# BMW      11179.000000
# Honda    62778.333333
# Nissan  122347.500000
# Toyota   85451.250000

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors       Price
# 0  Toyota  White         150043     4   $4,000.00
# 1   Honda    Red          87899     4   $5,000.00
# 2  Toyota   Blue          32549     3   $7,000.00
# 3     BMW  Black          11179     5  $22,000.00
# 4  Nissan  White         213095     4   $3,500.00
# 5  Toyota  Green          99213     4   $4,500.00
# 6   Honda   Blue          45698     4   $7,500.00
# 7   Honda   Blue          54738     4   $7,000.00
# 8  Toyota  White          60000     4   $6,250.00
# 9  Nissan  White          31600     4   $9,700.00

# %%
cars["Odometer (KM)"].plot()

# %%
cars["Odometer (KM)"].hist()

# %%
cars["Price"].dtype
# Out:
# dtype('O')

# %%
cars["Price"] = cars["Price"].str.replace("[\$\,\.]", "").astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price
# 0  Toyota  White         150043     4   400000
# 1   Honda    Red          87899     4   500000
# 2  Toyota   Blue          32549     3   700000
# 3     BMW  Black          11179     5  2200000
# 4  Nissan  White         213095     4   350000
# 5  Toyota  Green          99213     4   450000
# 6   Honda   Blue          45698     4   750000
# 7   Honda   Blue          54738     4   700000
# 8  Toyota  White          60000     4   625000
# 9  Nissan  White          31600     4   970000

# %%
cars["Price"].plot()

# %%
cars["Price"].hist()

# %% [markdown]
# ### Manipulating Data

# %%
cars["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price
# 0  Toyota  White         150043     4   400000
# 1   Honda    Red          87899     4   500000
# 2  Toyota   Blue          32549     3   700000
# 3     BMW  Black          11179     5  2200000
# 4  Nissan  White         213095     4   350000
# 5  Toyota  Green          99213     4   450000
# 6   Honda   Blue          45698     4   750000
# 7   Honda   Blue          54738     4   700000
# 8  Toyota  White          60000     4   625000
# 9  Nissan  White          31600     4   970000

# %%
cars["Make"] = cars["Make"].str.lower()

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price
# 0  toyota  White         150043     4   400000
# 1   honda    Red          87899     4   500000
# 2  toyota   Blue          32549     3   700000
# 3     bmw  Black          11179     5  2200000
# 4  nissan  White         213095     4   350000
# 5  toyota  Green          99213     4   450000
# 6   honda   Blue          45698     4   750000
# 7   honda   Blue          54738     4   700000
# 8  toyota  White          60000     4   625000
# 9  nissan  White          31600     4   970000

# %% [markdown]
# Manipulating Data

# %%
data = [{"Make":"Toyota","Colour":"White","Odometer":"150043","Doors":"4","Price":"$4,000"},{"Make":"Honda","Colour":"Red","Odometer":"87899","Doors":"4","Price":"$5,000"},{"Make":"Toyota","Colour":"Blue","Odometer":"","Doors":"3","Price":"$7,000"},{"Make":"BMW","Colour":"Black","Odometer":"11179","Doors":"5","Price":"$22,000"},{"Make":"Nissan","Colour":"White","Odometer":"213095","Doors":"4","Price":"$3,500"},{"Make":"Toyota","Colour":"Green","Odometer":"","Doors":"4","Price":"$4,500"},{"Make":"Honda","Colour":"","Odometer":"","Doors":"4","Price":"$7,500"},{"Make":"Honda","Colour":"Blue","Odometer":"","Doors":"4","Price":""},{"Make":"Toyota","Colour":"White","Odometer":"60000","Doors":"","Price":""},{"Make":"","Colour":"White","Odometer":"31600","Doors":"4","Price":"$9,700"}]


miss_cars = pd.DataFrame(data)


miss_cars
# Out:
#      Make Colour Odometer Doors    Price
# 0  Toyota  White   150043     4   $4,000
# 1   Honda    Red    87899     4   $5,000
# 2  Toyota   Blue              3   $7,000
# 3     BMW  Black    11179     5  $22,000
# 4  Nissan  White   213095     4   $3,500
# 5  Toyota  Green              4   $4,500
# 6   Honda                     4   $7,500
# 7   Honda   Blue              4
# 8  Toyota  White    60000
# 9          White    31600     4   $9,700

# %%
miss_cars["Odometer"] = miss_cars["Odometer"].fillna(miss_cars["Odometer"].mean(), inplace = True)

# %%
miss_cars
# Out:
#      Make Colour Odometer Doors    Price
# 0  Toyota  White     None     4   $4,000
# 1   Honda    Red     None     4   $5,000
# 2  Toyota   Blue     None     3   $7,000
# 3     BMW  Black     None     5  $22,000
# 4  Nissan  White     None     4   $3,500
# 5  Toyota  Green     None     4   $4,500
# 6   Honda            None     4   $7,500
# 7   Honda   Blue     None     4
# 8  Toyota  White     None
# 9          White     None     4   $9,700

# %%
miss_dropped_cars = miss_cars.dropna(inplace = True)
miss_dropped_cars

# %%
# Column from series


seats = pd.Series([5, 5, 5, 5, 5])
cars["Seats"] = seats

cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats
# 0  toyota  White         150043     4   400000    5.0
# 1   honda    Red          87899     4   500000    5.0
# 2  toyota   Blue          32549     3   700000    5.0
# 3     bmw  Black          11179     5  2200000    5.0
# 4  nissan  White         213095     4   350000    5.0
# 5  toyota  Green          99213     4   450000    NaN
# 6   honda   Blue          45698     4   750000    NaN
# 7   honda   Blue          54738     4   700000    NaN
# 8  toyota  White          60000     4   625000    NaN
# 9  nissan  White          31600     4   970000    NaN

# %%
cars["Seats"].fillna(5, inplace = True)

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats
# 0  toyota  White         150043     4   400000    5.0
# 1   honda    Red          87899     4   500000    5.0
# 2  toyota   Blue          32549     3   700000    5.0
# 3     bmw  Black          11179     5  2200000    5.0
# 4  nissan  White         213095     4   350000    5.0
# 5  toyota  Green          99213     4   450000    5.0
# 6   honda   Blue          45698     4   750000    5.0
# 7   honda   Blue          54738     4   700000    5.0
# 8  toyota  White          60000     4   625000    5.0
# 9  nissan  White          31600     4   970000    5.0

# %%
# Column from Python List


fuel = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
cars["Fuel"] = fuel
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel
# 0  toyota  White         150043     4   400000    5.0   7.5
# 1   honda    Red          87899     4   500000    5.0   9.2
# 2  toyota   Blue          32549     3   700000    5.0   5.0
# 3     bmw  Black          11179     5  2200000    5.0   9.6
# 4  nissan  White         213095     4   350000    5.0   8.7
# 5  toyota  Green          99213     4   450000    5.0   4.7
# 6   honda   Blue          45698     4   750000    5.0   7.6
# 7   honda   Blue          54738     4   700000    5.0   8.7
# 8  toyota  White          60000     4   625000    5.0   3.0
# 9  nissan  White          31600     4   970000    5.0   4.5

# %%
cars["Total Fuel (L)"] = cars["Odometer (KM)"] / 100 * cars["Fuel"]

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 0  toyota  White         150043     4   400000    5.0   7.5       11253.225
# 1   honda    Red          87899     4   500000    5.0   9.2        8086.708
# 2  toyota   Blue          32549     3   700000    5.0   5.0        1627.450
# 3     bmw  Black          11179     5  2200000    5.0   9.6        1073.184
# 4  nissan  White         213095     4   350000    5.0   8.7       18539.265
# 5  toyota  Green          99213     4   450000    5.0   4.7        4663.011
# 6   honda   Blue          45698     4   750000    5.0   7.6        3473.048
# 7   honda   Blue          54738     4   700000    5.0   8.7        4762.206
# 8  toyota  White          60000     4   625000    5.0   3.0        1800.000
# 9  nissan  White          31600     4   970000    5.0   4.5        1422.000
#
#    Wheels  Passed Road Safety  Safe  Total Fuel
# 0       4                True  True   11253.225
# ...

# %%
# Create a column from a single value


cars["Wheels"] = 4
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 0  toyota  White         150043     4   400000    5.0   7.5       11253.225
# 1   honda    Red          87899     4   500000    5.0   9.2        8086.708
# 2  toyota   Blue          32549     3   700000    5.0   5.0        1627.450
# 3     bmw  Black          11179     5  2200000    5.0   9.6        1073.184
# 4  nissan  White         213095     4   350000    5.0   8.7       18539.265
# 5  toyota  Green          99213     4   450000    5.0   4.7        4663.011
# 6   honda   Blue          45698     4   750000    5.0   7.6        3473.048
# 7   honda   Blue          54738     4   700000    5.0   8.7        4762.206
# 8  toyota  White          60000     4   625000    5.0   3.0        1800.000
# 9  nissan  White          31600     4   970000    5.0   4.5        1422.000
#
#    Wheels  Passed Road Safety  Safe  Total Fuel
# 0       4                True  True   11253.225
# ...

# %%
cars["Safe"] = True

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 0  toyota  White         150043     4   400000    5.0   7.5       11253.225
# 1   honda    Red          87899     4   500000    5.0   9.2        8086.708
# 2  toyota   Blue          32549     3   700000    5.0   5.0        1627.450
# 3     bmw  Black          11179     5  2200000    5.0   9.6        1073.184
# 4  nissan  White         213095     4   350000    5.0   8.7       18539.265
# 5  toyota  Green          99213     4   450000    5.0   4.7        4663.011
# 6   honda   Blue          45698     4   750000    5.0   7.6        3473.048
# 7   honda   Blue          54738     4   700000    5.0   8.7        4762.206
# 8  toyota  White          60000     4   625000    5.0   3.0        1800.000
# 9  nissan  White          31600     4   970000    5.0   4.5        1422.000
#
#    Wheels  Passed Road Safety  Safe  Total Fuel
# 0       4                True  True   11253.225
# ...

# %%
# Delete a column


cars = cars.drop("Total Fuel", axis = 1)

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 0  toyota  White         150043     4   400000    5.0   7.5       11253.225
# 1   honda    Red          87899     4   500000    5.0   9.2        8086.708
# 2  toyota   Blue          32549     3   700000    5.0   5.0        1627.450
# 3     bmw  Black          11179     5  2200000    5.0   9.6        1073.184
# 4  nissan  White         213095     4   350000    5.0   8.7       18539.265
# 5  toyota  Green          99213     4   450000    5.0   4.7        4663.011
# 6   honda   Blue          45698     4   750000    5.0   7.6        3473.048
# 7   honda   Blue          54738     4   700000    5.0   8.7        4762.206
# 8  toyota  White          60000     4   625000    5.0   3.0        1800.000
# 9  nissan  White          31600     4   970000    5.0   4.5        1422.000
#
#    Wheels  Passed Road Safety  Safe
# 0       4                True  True
# 1       4                True  True
# ...

# %%
cars = cars.drop("Passed Road Safety", axis = 1)

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 0  toyota  White         150043     4   400000    5.0   7.5       11253.225
# 1   honda    Red          87899     4   500000    5.0   9.2        8086.708
# 2  toyota   Blue          32549     3   700000    5.0   5.0        1627.450
# 3     bmw  Black          11179     5  2200000    5.0   9.6        1073.184
# 4  nissan  White         213095     4   350000    5.0   8.7       18539.265
# 5  toyota  Green          99213     4   450000    5.0   4.7        4663.011
# 6   honda   Blue          45698     4   750000    5.0   7.6        3473.048
# 7   honda   Blue          54738     4   700000    5.0   8.7        4762.206
# 8  toyota  White          60000     4   625000    5.0   3.0        1800.000
# 9  nissan  White          31600     4   970000    5.0   4.5        1422.000
#
#    Wheels  Safe
# 0       4  True
# 1       4  True
# 2       4  True
# 3       4  True
# 4       4  True
# 5       4  True
# ...

# %%
cars.sample(frac = 0.5)
# Out:
#      Make Colour  Odometer (KM) Doors   Price  Seats  Fuel  Total Fuel (L)  \
# 1   honda    Red          87899     4  500000    5.0   9.2        8086.708
# 2  toyota   Blue          32549     3  700000    5.0   5.0        1627.450
# 0  toyota  White         150043     4  400000    5.0   7.5       11253.225
# 4  nissan  White         213095     4  350000    5.0   8.7       18539.265
# 5  toyota  Green          99213     4  450000    5.0   4.7        4663.011
#
#    Wheels  Safe
# 1       4  True
# 2       4  True
# 0       4  True
# 4       4  True
# 5       4  True

# %%
cars_shuffled = cars.sample(frac = 1)

# %%
cars_shuffled
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 5  toyota  Green          99213     4   450000    5.0   4.7        4663.011
# 0  toyota  White         150043     4   400000    5.0   7.5       11253.225
# 2  toyota   Blue          32549     3   700000    5.0   5.0        1627.450
# 7   honda   Blue          54738     4   700000    5.0   8.7        4762.206
# 6   honda   Blue          45698     4   750000    5.0   7.6        3473.048
# 8  toyota  White          60000     4   625000    5.0   3.0        1800.000
# 1   honda    Red          87899     4   500000    5.0   9.2        8086.708
# 3     bmw  Black          11179     5  2200000    5.0   9.6        1073.184
# 9  nissan  White          31600     4   970000    5.0   4.5        1422.000
# 4  nissan  White         213095     4   350000    5.0   8.7       18539.265
#
#    Wheels  Safe
# 5       4  True
# 0       4  True
# 2       4  True
# 7       4  True
# 6       4  True
# 8       4  True
# ...

# %%
# Only select 20% of data

cars_shuffled.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM) Doors   Price  Seats  Fuel  Total Fuel (L)  \
# 8  toyota  White          60000     4  625000    5.0   3.0         1800.00
# 2  toyota   Blue          32549     3  700000    5.0   5.0         1627.45
#
#    Wheels  Safe
# 8       4  True
# 2       4  True

# %%
cars_shuffled
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 5  toyota  Green          99213     4   450000    5.0   4.7        4663.011
# 0  toyota  White         150043     4   400000    5.0   7.5       11253.225
# 2  toyota   Blue          32549     3   700000    5.0   5.0        1627.450
# 7   honda   Blue          54738     4   700000    5.0   8.7        4762.206
# 6   honda   Blue          45698     4   750000    5.0   7.6        3473.048
# 8  toyota  White          60000     4   625000    5.0   3.0        1800.000
# 1   honda    Red          87899     4   500000    5.0   9.2        8086.708
# 3     bmw  Black          11179     5  2200000    5.0   9.6        1073.184
# 9  nissan  White          31600     4   970000    5.0   4.5        1422.000
# 4  nissan  White         213095     4   350000    5.0   8.7       18539.265
#
#    Wheels  Safe
# 5       4  True
# 0       4  True
# 2       4  True
# 7       4  True
# 6       4  True
# 8       4  True
# ...

# %%
cars_shuffled.reset_index(drop = True, inplace = True)

# %%
cars_shuffled
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 0  toyota  Green          99213     4   450000    5.0   4.7        4663.011
# 1  toyota  White         150043     4   400000    5.0   7.5       11253.225
# 2  toyota   Blue          32549     3   700000    5.0   5.0        1627.450
# 3   honda   Blue          54738     4   700000    5.0   8.7        4762.206
# 4   honda   Blue          45698     4   750000    5.0   7.6        3473.048
# 5  toyota  White          60000     4   625000    5.0   3.0        1800.000
# 6   honda    Red          87899     4   500000    5.0   9.2        8086.708
# 7     bmw  Black          11179     5  2200000    5.0   9.6        1073.184
# 8  nissan  White          31600     4   970000    5.0   4.5        1422.000
# 9  nissan  White         213095     4   350000    5.0   8.7       18539.265
#
#    Wheels  Safe
# 0       4  True
# 1       4  True
# 2       4  True
# 3       4  True
# 4       4  True
# 5       4  True
# ...

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 0  toyota  White      93776.875     4   400000    5.0   7.5       11253.225
# 1   honda    Red      54936.875     4   500000    5.0   9.2        8086.708
# 2  toyota   Blue      20343.125     3   700000    5.0   5.0        1627.450
# 3     bmw  Black       6986.875     5  2200000    5.0   9.6        1073.184
# 4  nissan  White     133184.375     4   350000    5.0   8.7       18539.265
# 5  toyota  Green      62008.125     4   450000    5.0   4.7        4663.011
# 6   honda   Blue      28561.250     4   750000    5.0   7.6        3473.048
# 7   honda   Blue      34211.250     4   700000    5.0   8.7        4762.206
# 8  toyota  White      37500.000     4   625000    5.0   3.0        1800.000
# 9  nissan  White      19750.000     4   970000    5.0   4.5        1422.000
#
#    Wheels  Safe
# 0       4  True
# 1       4  True
# 2       4  True
# 3       4  True
# 4       4  True
# 5       4  True
# ...

# %%
cars["Odometer (KM)"] = cars["Odometer (KM)"].apply(lambda x: x / 1.6)

# %%
cars
# Out:
#      Make Colour  Odometer (KM) Doors    Price  Seats  Fuel  Total Fuel (L)  \
# 0  toyota  White      93776.875     4   400000    5.0   7.5       11253.225
# 1   honda    Red      54936.875     4   500000    5.0   9.2        8086.708
# 2  toyota   Blue      20343.125     3   700000    5.0   5.0        1627.450
# 3     bmw  Black       6986.875     5  2200000    5.0   9.6        1073.184
# 4  nissan  White     133184.375     4   350000    5.0   8.7       18539.265
# 5  toyota  Green      62008.125     4   450000    5.0   4.7        4663.011
# 6   honda   Blue      28561.250     4   750000    5.0   7.6        3473.048
# 7   honda   Blue      34211.250     4   700000    5.0   8.7        4762.206
# 8  toyota  White      37500.000     4   625000    5.0   3.0        1800.000
# 9  nissan  White      19750.000     4   970000    5.0   4.5        1422.000
#
#    Wheels  Safe
# 0       4  True
# 1       4  True
# 2       4  True
# 3       4  True
# 4       4  True
# 5       4  True
# ...
